# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.835024
# Nearest to had: encounters, schiff, auschwitz, slanted, lom, lecturing, dropouts, medica,
# Nearest to as: upn, currying, balboa, kiwifruit, provably, hallows, defective, rewarded,
# Nearest to time: reuniting, renounced, ido, terrain, migratory, codec, downwind, chainsaw,
# Nearest to world: insisted, rik, tartarus, drift, sennett, goi, curves, firmware,
# Nearest to been: understated, attract, saxons, sandworms, hereafter, dealer, insurrections, uranium,
# Nearest to so: infested, festivals, skywalker, barbarous, via, parmenides, singled, zoster,
# Nearest to war: canonized, mortally, woolen, aerodynamics, longstanding, sarmatian, wool, predicate,
# Nearest to only: korn, cryptic, instituted, enjoys, implausible, taipei, xis, nicknames,
# Nearest to most: centralisation, salamanca, ugly, indisputable, myself, ferrol, nter, avignon,
# Nearest to years: talmudic, jolla, tcp, joram, neusner, cyborgs, hometown, bulgarian,
# Nearest to some: pongo, euroscepticism, scandinavian, seng, haliotis, astute, nt, nail,
# Nearest to are: horrible, maoist, eckhart, kiribati, coin, unabomber, dear, ibf,
# Nearest to over: casein, banchan, trump, medlineplus, auto, leakage, transhuman, oracular,
# Nearest to it: crowning, extract, streaks, depth, wiesenthal, mace, robson, chaplin,
# Nearest to i: siddeley, viv, noise, botticelli, ellipse, shadows, reconciliation, semi,
# Nearest to two: locke, ecstatic, embalming, chileans, avalanches, untouched, pantheism, cookie,
# Average loss at step 2000: 4.371361
# Average loss at step 4000: 3.861337
# Average loss at step 6000: 3.778395
# Average loss at step 8000: 3.690521
# Average loss at step 10000: 3.613544
# Nearest to had: has, have, was, must, tetra, gcc, notables, kirk,
# Nearest to as: triage, violations, in, when, handing, hypothetical, blower, subpoenaed,
# Nearest to time: reuniting, modena, dig, harbours, levi, illiterate, edicts, itchy,
# Nearest to world: largest, hot, insisted, censorial, protocol, parties, curves, tartarus,
# Nearest to been: were, by, subpage, hellene, be, had, sandworms, maitland,
# Nearest to so: headset, zo, algebraic, metaphorically, samhain, persists, hamito, locke,
# Nearest to war: joliet, zuid, banquet, traditions, subscription, mortally, pipers, woolen,
# Nearest to only: instituted, albatrosses, genocide, cryptic, florin, distantly, illuminatus, hermon,
# Nearest to most: centralisation, salamanca, myself, harlan, workloads, ugly, nter, romney,
# Nearest to years: jolla, tcp, talmudic, joram, romantic, astray, disjunction, euroscepticism,
# Nearest to some: many, pongo, falk, euroscepticism, tonic, sable, purportedly, abb,
# Nearest to are: were, is, have, fiddler, patriots, fujimori, shirley, was,
# Nearest to over: crumb, stark, gandhara, reoccupied, controlled, auto, casein, pushkin,
# Nearest to it: he, this, there, that, they, which, she, not,
# Nearest to i: berenguer, viv, collins, siddeley, pam, he, conrad, srpska,
# Nearest to two: three, four, five, one, seven, six, eight, nine,
# Average loss at step 12000: 3.606384
# Average loss at step 14000: 3.567634
# Average loss at step 16000: 3.410621
# Average loss at step 18000: 3.457940
# Average loss at step 20000: 3.539846
# Nearest to had: has, have, was, were, been, since, eleusinian, totalled,
# Nearest to as: when, triage, combustible, strong, wraith, subpoenaed, defective, for,
# Nearest to time: reuniting, fact, itchy, bower, illiterate, saarc, harbours, randle,
# Nearest to world: largest, hot, censorial, parties, moon, rik, tartarus, insisted,
# Nearest to been: be, were, become, had, by, mnp, subpage, was,
# Nearest to so: algebraic, headset, zo, partitioning, locke, metaphorically, antithetical, hamito,
# Nearest to war: drank, horsemanship, zuid, banquet, search, subscription, israel, meinhof,
# Nearest to only: albatrosses, cryptic, genocide, instituted, illuminatus, florin, multipurpose, chat,
# Nearest to most: more, centralisation, some, harlan, coleridge, tapestry, dect, adversarial,
# Nearest to years: jolla, months, tcp, forestry, talmudic, romantic, astray, days,
# Nearest to some: many, several, these, all, falk, most, his, various,
# Nearest to are: were, is, have, shirley, horrible, was, seriously, be,
# Nearest to over: crumb, sympathizers, gandhara, lightest, stark, leakage, controlled, casein,
# Nearest to it: he, this, there, she, which, they, not, draftees,
# Nearest to i: ii, we, siddeley, you, tee, viv, collins, conrad,
# Nearest to two: three, five, four, six, eight, one, seven, zero,
# Average loss at step 22000: 3.499597
# Average loss at step 24000: 3.485366
# Average loss at step 26000: 3.483895
# Average loss at step 28000: 3.479709
# Average loss at step 30000: 3.510453
# Nearest to had: has, have, was, were, since, been, did, discrepancy,
# Nearest to as: triage, became, shaky, when, combustible, whilst, electress, anglicised,
# Nearest to time: reuniting, coprocessor, modena, play, migratory, world, metric, randle,
# Nearest to world: largest, protocol, parties, hot, nonce, shorty, team, sarajevo,
# Nearest to been: become, were, be, was, already, had, subpage, battlecruisers,
# Nearest to so: headset, locke, antithetical, partitioning, too, hamito, educational, eventually,
# Nearest to war: zuid, banquet, israel, joliet, fans, manned, sabbatical, horsemanship,
# Nearest to only: excited, genocide, multipurpose, albatrosses, snoopy, cryptic, cul, seized,
# Nearest to most: more, coleridge, blizzards, some, acute, harlan, buyers, romney,
# Nearest to years: months, days, jolla, times, weeks, forestry, centuries, tcp,
# Nearest to some: many, these, several, all, other, their, various, pliny,
# Nearest to are: were, have, is, bian, include, be, while, mordant,
# Nearest to over: crumb, leakage, lightest, gandhara, stark, sympathizers, through, sympathetic,
# Nearest to it: he, there, this, she, they, draftees, cement, which,
# Nearest to i: ii, you, we, collins, iii, tee, rik, frac,
# Nearest to two: four, five, three, one, eight, seven, six, nine,
# Average loss at step 32000: 3.499097
# Average loss at step 34000: 3.490037
# Average loss at step 36000: 3.456858
# Average loss at step 38000: 3.301534
# Average loss at step 40000: 3.428931
# Nearest to had: has, have, was, were, since, been, having, would,
# Nearest to as: by, when, haste, thom, bearded, lysosome, cahokia, provably,
# Nearest to time: fact, play, year, saarc, reuniting, bax, bonny, say,
# Nearest to world: largest, shorty, protocol, sarajevo, nonce, hot, cistern, algonquian,
# Nearest to been: become, be, was, had, already, were, hallucinatory, battlecruisers,
# Nearest to so: too, hamito, morley, locke, partitioning, headset, bony, antithetical,
# Nearest to war: banquet, israel, horsemanship, hail, piacenza, adventurous, manned, flogging,
# Nearest to only: excited, cryptic, albatrosses, genocide, snoopy, tropic, counterexamples, essentially,
# Nearest to most: more, harlan, acute, claudel, swami, whitish, many, some,
# Nearest to years: months, days, times, jolla, weeks, centuries, tcp, year,
# Nearest to some: many, these, several, various, other, any, their, waterbury,
# Nearest to are: were, is, have, be, shirley, sustenance, crackers, mordant,
# Nearest to over: through, ground, sera, fta, decins, nearly, congresses, bits,
# Nearest to it: he, there, she, this, they, which, not, but,
# Nearest to i: ii, you, we, t, collins, frac, they, rik,
# Nearest to two: three, four, five, seven, six, one, eight, nine,
# Average loss at step 42000: 3.434648
# Average loss at step 44000: 3.459653
# Average loss at step 46000: 3.450076
# Average loss at step 48000: 3.354520
# Average loss at step 50000: 3.380026
# Nearest to had: has, have, was, were, having, since, been, did,
# Nearest to as: anatta, haste, when, combustible, vfl, glow, saterland, adlai,
# Nearest to time: year, coprocessor, bax, chapter, soundtracks, moniker, constituted, bonny,
# Nearest to world: largest, liberals, protocol, shorty, nonce, desmodromic, traffickers, implicitly,
# Nearest to been: become, be, was, were, had, hallucinatory, already, previously,
# Nearest to so: then, morley, hamito, too, bony, eventually, headset, grades,
# Nearest to war: israel, ultima, demonstration, banquet, manned, adventurous, frisian, drank,
# Nearest to only: cryptic, excited, albatrosses, snoopy, tropic, currently, cul, still,
# Nearest to most: more, some, less, harlan, westwood, claudel, buyers, many,
# Nearest to years: days, months, weeks, times, centuries, jolla, year, talmudic,
# Nearest to some: many, several, these, various, other, most, both, the,
# Nearest to are: were, have, is, be, these, mordant, although, those,
# Nearest to over: through, lightest, parcel, sera, into, decins, fta, ground,
# Nearest to it: he, there, she, this, they, cement, not, inexplicable,
# Nearest to i: we, you, ii, collins, t, caenorhabditis, tee, frac,
# Nearest to two: three, four, six, eight, five, seven, one, nine,
# Average loss at step 52000: 3.433172
# Average loss at step 54000: 3.429585
# Average loss at step 56000: 3.439779
# Average loss at step 58000: 3.395955
# Average loss at step 60000: 3.395406
# Nearest to had: has, have, was, having, were, did, been, yet,
# Nearest to as: when, regicide, haste, naive, lysosome, extraordinary, anatta, meals,
# Nearest to time: constituted, blow, coprocessor, bax, reuniting, year, moniker, bonny,
# Nearest to world: largest, algonquian, liberals, sarajevo, nonce, protocol, magnetopause, implicitly,
# Nearest to been: become, be, was, had, were, hallucinatory, ruthlessness, endorses,
# Nearest to so: too, hamito, morley, then, detrimental, participles, grades, sneak,
# Nearest to war: israel, ultima, demonstration, banquet, manned, piacenza, hail, zuid,
# Nearest to only: excited, cryptic, currently, snoopy, albatrosses, still, until, utilize,
# Nearest to most: more, some, many, less, acute, use, westwood, etymology,
# Nearest to years: days, months, weeks, times, centuries, year, talmudic, decades,
# Nearest to some: many, several, these, various, most, each, waterbury, those,
# Nearest to are: were, is, have, be, those, mordant, these, interferes,
# Nearest to over: through, around, within, mailbox, about, parcel, into, decins,
# Nearest to it: he, there, she, this, what, they, which, trick,
# Nearest to i: we, you, ii, collins, g, t, frac, topography,
# Nearest to two: three, four, five, six, one, eight, seven, nine,
# Average loss at step 62000: 3.241238
# Average loss at step 64000: 3.252670
# Average loss at step 66000: 3.402400
# Average loss at step 68000: 3.394309
# Average loss at step 70000: 3.362719
# Nearest to had: has, have, was, having, were, since, been, did,
# Nearest to as: regicide, haste, by, is, when, like, for, combustible,
# Nearest to time: reuniting, year, constituted, coprocessor, bax, bonny, chapter, way,
# Nearest to world: largest, shorty, liars, algonquian, madonna, implicitly, started, epimenides,
# Nearest to been: become, be, was, hallucinatory, were, had, already, traditionally,
# Nearest to so: thus, too, grades, hamito, vito, sneak, then, morley,
# Nearest to war: ultima, israel, banquet, demonstration, conveying, manned, evacuate, terrorism,
# Nearest to only: still, cryptic, both, normally, currently, creature, haryana, every,
# Nearest to most: more, less, many, particularly, use, some, whitish, pcb,
# Nearest to years: days, months, weeks, centuries, decades, times, year, percent,
# Nearest to some: many, several, these, various, all, other, any, waterbury,
# Nearest to are: were, is, have, although, these, while, including, those,
# Nearest to over: through, decins, around, parcel, within, stark, mailbox, cynics,
# Nearest to it: he, there, she, this, they, still, draftees, what,
# Nearest to i: we, you, ii, collins, g, transforms, frac, conrad,
# Nearest to two: three, six, four, five, seven, one, eight, zero,
# Average loss at step 72000: 3.371860
# Average loss at step 74000: 3.346448
# Average loss at step 76000: 3.315899
# Average loss at step 78000: 3.353449
# Average loss at step 80000: 3.377289
# Nearest to had: have, has, having, were, was, began, did, since,
# Nearest to as: lysosome, burgesses, before, provably, when, wr, haste, absalon,
# Nearest to time: reuniting, year, moniker, constituted, extent, rhenish, game, bax,
# Nearest to world: largest, liars, started, algonquian, madonna, shorty, sank, liberals,
# Nearest to been: become, be, hallucinatory, was, were, already, recently, being,
# Nearest to so: too, thus, grades, vito, sneak, then, however, hamito,
# Nearest to war: israel, manned, ultima, banquet, tactician, terrorism, demonstration, frisian,
# Nearest to only: still, cryptic, tropic, creature, haryana, normally, ying, motorway,
# Nearest to most: more, many, some, particularly, less, among, acute, westwood,
# Nearest to years: days, months, weeks, centuries, decades, year, times, minutes,
# Nearest to some: many, several, various, these, most, multiple, any, certain,
# Nearest to are: were, is, have, include, although, including, these, require,
# Nearest to over: through, around, within, cynics, cosmogony, decins, about, nearly,
# Nearest to it: he, she, there, this, draftees, they, never, still,
# Nearest to i: we, you, ii, collins, g, iii, frac, conrad,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Average loss at step 82000: 3.410050
# Average loss at step 84000: 3.411999
# Average loss at step 86000: 3.390432
# Average loss at step 88000: 3.352119
# Average loss at step 90000: 3.367759
# Nearest to had: has, have, was, having, were, since, did, began,
# Nearest to as: haste, consultancy, dimorphism, erv, anatta, frege, dino, by,
# Nearest to time: reuniting, moniker, constituted, year, athenian, zoe, blow, impressed,
# Nearest to world: algonquian, liars, shorty, started, liberals, madonna, canaris, implicitly,
# Nearest to been: become, be, was, already, hallucinatory, traditionally, were, recently,
# Nearest to so: thus, too, hamito, before, dared, if, antithetical, baffin,
# Nearest to war: ultima, demonstration, tactician, banquet, urbino, solidifies, terrorism, israel,
# Nearest to only: cryptic, still, every, always, no, currently, tropic, albatrosses,
# Nearest to most: many, more, less, particularly, some, among, claudel, notion,
# Nearest to years: days, months, weeks, decades, centuries, year, minutes, times,
# Nearest to some: many, several, these, various, all, most, any, both,
# Nearest to are: were, is, have, include, these, although, mordant, those,
# Nearest to over: through, around, within, cosmogony, cynics, stamina, about, off,
# Nearest to it: he, there, she, this, they, never, draftees, still,
# Nearest to i: ii, we, frac, you, collins, g, conrad, viii,
# Nearest to two: three, four, five, seven, eight, six, one, nine,
# Average loss at step 92000: 3.399171
# Average loss at step 94000: 3.251315
# Average loss at step 96000: 3.355389
# Average loss at step 98000: 3.240595
# Average loss at step 100000: 3.357706
# Nearest to had: has, have, having, was, were, gets, since, is,
# Nearest to as: like, anatta, raisonn, dino, including, haste, via, combustible,
# Nearest to time: constituted, year, moniker, depth, glissando, rhenish, athenian, bax,
# Nearest to world: shorty, algonquian, liars, madonna, sank, glottal, started, purposes,
# Nearest to been: become, be, already, recently, was, previously, hallucinatory, traditionally,
# Nearest to so: thus, too, vito, antithetical, when, then, hamito, eventually,
# Nearest to war: manned, urbino, ultima, terrorism, israel, banquet, tactician, demonstration,
# Nearest to only: still, cryptic, no, every, deemed, motorway, currently, never,
# Nearest to most: more, less, particularly, among, notion, especially, pcb, buyers,
# Nearest to years: days, months, weeks, decades, centuries, year, times, minutes,
# Nearest to some: many, several, these, any, various, all, certain, this,
# Nearest to are: were, include, have, those, is, although, firmus, mordant,
# Nearest to over: within, around, between, through, about, cosmogony, cynics, sera,
# Nearest to it: he, she, this, there, they, what, still, never,
# Nearest to i: we, you, ii, frac, collins, iii, conrad, they,
# Nearest to two: three, four, five, six, seven, eight, one, nine,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# CBOW

data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, bag_window * 2), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    target = bag_window  # target label at the center of the buffer
    tmp = list(buffer)
    batch[i] = tmp[:target] + tmp[target+1:]
    labels[i, 0] = tmp[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % bag_window)
    print('    batch:', [[reverse_dictionary[ci] for ci in context] for context in batch])

    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
# CBOW

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
#valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.820716
# Nearest to had: gozo, rollers, fractals, saratoga, milton, hooded, diabetic, savanna,
# Nearest to as: columbanus, finlay, bannockburn, hijack, widening, obligate, champion, subdivisions,
# Nearest to time: search, patagonian, milli, indivisible, agave, perforce, intelsat, aberdare,
# Nearest to world: consul, nero, nederlandse, flamethrower, dinosaur, khad, ny, deserved,
# Nearest to been: lendl, xj, seals, marilyn, receive, nails, constructors, jaffna,
# Nearest to so: extensible, ene, superseding, sorcerers, geometries, marksmen, valuables, famous,
# Nearest to war: pottery, abandons, siona, otimes, vinod, factions, multiparty, uther,
# Nearest to only: wexford, sor, benoit, motte, mut, samos, wren, saltzer,
# Nearest to most: marshlands, interplanetary, juniper, tanistry, faring, tupper, ternary, tahitian,
# Nearest to years: hillel, lips, dashed, palatal, cro, huffman, moth, jeffreys,
# Nearest to some: velvet, devastates, denials, antimony, knighted, bollywood, meatball, panyu,
# Nearest to are: portals, affecting, rules, carnahan, baudot, gardner, patrilineal, carrion,
# Nearest to over: since, turret, alleging, grayson, tropical, jardines, rimbaud, avram,
# Nearest to it: herat, springs, fulton, cadre, talmadge, evangelism, summertime, seneca,
# Nearest to i: robbing, heal, cuba, thistle, pools, effecting, commodore, rangle,
# Nearest to two: eigenvalue, ravalomanana, predicting, body, bayonet, faithful, disciples, israel,

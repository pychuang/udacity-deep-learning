# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'as', 'of', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.631221
# Nearest to its: phony, yastrzemski, diodes, gazing, propagandists, february, angiosperms, caste,
# Nearest to known: damascus, clubhouse, amano, primogeniture, kilowatts, timor, kelley, tide,
# Nearest to it: position, solubility, whitespace, mamma, parochial, welsh, telegraphic, silicone,
# Nearest to four: grotesque, almanac, codices, jongg, lighten, homily, bikes, er,
# Nearest to were: dah, cassiodorus, vfr, hillbillies, kohen, odour, pandit, nilsson,
# Nearest to b: bram, pete, infiltrate, torch, equivocal, chorale, rubenstein, ciii,
# Nearest to states: tesla, teutonic, religiously, hc, deflate, ackerman, monographs, trent,
# Nearest to as: donohue, zinc, embellished, fermion, roscoe, dans, pilots, manifestos,
# Nearest to history: milos, staggered, regular, duelling, pilgrims, seasoning, barn, hamburgers,
# Nearest to or: compton, marion, hasbro, foam, boring, schiff, profane, leaps,
# Nearest to he: perpetuating, srinagar, versus, stubby, traditionalists, housman, heroism, dedham,
# Nearest to also: fossilization, pentium, flatted, schlesinger, eazy, hitpa, rito, nature,
# Nearest to than: reports, tenure, sonnets, modelled, hungary, entitled, raps, taming,
# Nearest to would: guglielmo, oort, helier, epicenter, differential, summa, algemeen, dependents,
# Nearest to on: unwillingly, consequentialism, flambards, ecclesiastic, andean, methamphetamine, infallible, cellar,
# Nearest to no: adas, reals, loosening, disarmed, impressions, solubility, continuously, complex,
# Average loss at step 2000: 4.366247
# Average loss at step 4000: 3.870642
# Average loss at step 6000: 3.785919
# Average loss at step 8000: 3.687600
# Average loss at step 10000: 3.615545
# Nearest to its: the, his, their, deceit, this, provinces, anorexia, mouths,
# Nearest to known: sucked, thermals, regarded, damascus, such, haitians, viewers, tide,
# Nearest to it: he, this, not, there, they, also, that, which,
# Nearest to four: six, three, five, eight, seven, two, zero, nine,
# Nearest to were: are, was, have, pirates, had, by, fastened, syndromes,
# Nearest to b: d, pete, bram, infiltrate, nlds, nel, intractable, equivocal,
# Nearest to states: sacrament, hc, muppets, casta, catolica, halfback, religiously, airshows,
# Nearest to as: zinc, pluralist, roscoe, ohlin, ethica, lounge, fergana, by,
# Nearest to history: rancid, legislated, staggered, herbalists, duelling, everett, barn, milos,
# Nearest to or: and, incrimination, guernica, ptolemy, ignorant, overcoming, superstructure, ullmann,
# Nearest to he: it, she, they, there, who, dismantling, lyle, which,
# Nearest to also: pentium, it, which, who, hejaz, macabre, pictured, min,
# Nearest to than: reports, tenure, sundays, aquaria, players, dmd, chocolates, popper,
# Nearest to would: may, can, could, guglielmo, unorthodox, oort, will, zz,
# Nearest to on: in, from, at, of, vast, curricula, agp, around,
# Nearest to no: adas, reals, instantaneous, liqueurs, heimdall, loosening, continuously, it,
# Average loss at step 12000: 3.605457
# Average loss at step 14000: 3.570087
# Average loss at step 16000: 3.410742
# Average loss at step 18000: 3.460109
# Average loss at step 20000: 3.539091
# Nearest to its: their, his, the, her, some, agricultural, deceit, anorexia,
# Nearest to known: regarded, such, sucked, thermals, viewers, tide, thorax, haitians,
# Nearest to it: he, this, there, also, she, not, which, they,
# Nearest to four: six, three, five, seven, eight, two, nine, zero,
# Nearest to were: are, was, had, have, be, is, fries, mash,
# Nearest to b: d, pete, multics, infiltrate, bram, intractable, dutch, horrific,
# Nearest to states: kingdom, completion, airshows, catolica, muppets, gendarmerie, pastimes, casta,
# Nearest to as: tailed, transitions, zinc, ethica, for, biography, lounge, pluralist,
# Nearest to history: classicists, legislated, organizing, start, acrobatics, barn, tribulations, everett,
# Nearest to or: and, than, yung, incrimination, episodic, eprint, differentiable, lactase,
# Nearest to he: it, she, they, who, there, totally, never, indulgence,
# Nearest to also: which, it, who, pentium, often, not, then, macabre,
# Nearest to than: reports, or, way, tenure, sundays, aotearoa, players, mcnally,
# Nearest to would: may, can, could, will, should, must, override, might,
# Nearest to on: in, at, curricula, agp, fashion, from, upon, through,
# Nearest to no: adas, complex, heimdall, instantaneous, reals, fiercest, continuously, kazakh,
# Average loss at step 22000: 3.500041
# Average loss at step 24000: 3.486626
# Average loss at step 26000: 3.480318
# Average loss at step 28000: 3.480610
# Average loss at step 30000: 3.500747
# Nearest to its: their, the, his, her, some, reforestation, soo, a,
# Nearest to known: regarded, such, used, sucked, described, viewers, thermals, thorax,
# Nearest to it: he, there, this, she, they, which, not, noted,
# Nearest to four: five, six, eight, three, seven, two, nine, zero,
# Nearest to were: are, was, have, had, been, sympathizers, mash, compliment,
# Nearest to b: d, multics, pete, bram, alford, marl, societal, intractable,
# Nearest to states: airshows, kingdom, completion, catolica, bea, facilitates, state, casta,
# Nearest to as: tailed, ohlin, ethica, fergana, petitcodiac, bsa, by, became,
# Nearest to history: classicists, organizing, tribulations, acrobatics, everett, clothing, barn, legislated,
# Nearest to or: and, clustered, ptolemy, incrimination, when, without, photographers, than,
# Nearest to he: she, it, they, who, there, thunderbird, detainee, ombudsman,
# Nearest to also: often, which, still, now, who, it, generally, replied,
# Nearest to than: way, reports, balloon, marche, carolinas, but, deoxyribonucleic, sundays,
# Nearest to would: may, can, could, will, must, should, might, cannot,
# Nearest to on: upon, in, through, from, at, transfusion, about, around,
# Nearest to no: adas, complex, heimdall, rayner, reals, not, goto, continuously,
# Average loss at step 32000: 3.502244
# Average loss at step 34000: 3.495321
# Average loss at step 36000: 3.457836
# Average loss at step 38000: 3.304031
# Average loss at step 40000: 3.432564
# Nearest to its: their, his, the, her, labs, your, durable, rooftops,
# Nearest to known: regarded, such, used, described, viewers, thorax, sucked, thermals,
# Nearest to it: he, there, she, this, they, which, noted, often,
# Nearest to four: six, five, three, two, seven, eight, nine, one,
# Nearest to were: are, have, was, had, be, been, compliment, mash,
# Nearest to b: d, n, c, pete, UNK, r, stanzas, susan,
# Nearest to states: kingdom, airshows, nations, completion, gendarmerie, catolica, state, clipping,
# Nearest to as: petitcodiac, pluralist, jubilees, submerged, ethica, when, lounge, ravaged,
# Nearest to history: organizing, vast, art, peripheries, contemplated, differentiation, treaties, lakeside,
# Nearest to or: and, a, than, evils, dib, tavistock, monsoon, episodic,
# Nearest to he: she, it, they, who, there, i, dylan, eventually,
# Nearest to also: often, which, now, generally, still, widely, who, typically,
# Nearest to than: or, way, marche, cadr, much, aotearoa, hermeneutic, reports,
# Nearest to would: could, will, may, can, should, must, might, did,
# Nearest to on: upon, transfusion, through, during, from, at, agp, about,
# Nearest to no: adas, rayner, complex, continuously, any, asymptotic, heimdall, instantaneous,
# Average loss at step 42000: 3.436642
# Average loss at step 44000: 3.453484
# Average loss at step 46000: 3.450670
# Average loss at step 48000: 3.355209
# Average loss at step 50000: 3.382992
# Nearest to its: their, his, the, her, your, my, rooftops, whose,
# Nearest to known: regarded, used, such, described, possible, viewers, sucked, part,
# Nearest to it: he, she, there, this, they, methyl, then, often,
# Nearest to four: three, five, six, seven, eight, nine, two, one,
# Nearest to were: are, was, have, had, been, be, although, fries,
# Nearest to b: d, c, stanzas, johnson, nikita, easter, f, r,
# Nearest to states: kingdom, nations, airshows, dams, euros, state, muppets, catolica,
# Nearest to as: ohlin, reformed, petitcodiac, lakota, fergana, lesser, sequel, shadowed,
# Nearest to history: organizing, book, acrobatics, church, vast, gwen, courant, art,
# Nearest to or: and, than, leans, burgesses, tavistock, but, constructor, tobin,
# Nearest to he: she, it, they, there, who, i, dylan, this,
# Nearest to also: often, which, now, still, typically, who, then, actually,
# Nearest to than: hermeneutic, or, cadr, but, strides, much, aotearoa, even,
# Nearest to would: will, could, may, can, should, must, might, cannot,
# Nearest to on: upon, through, in, at, transfusion, curricula, vast, around,
# Nearest to no: any, adas, little, asymptotic, rayner, goto, delineated, planner,
# Average loss at step 52000: 3.436100
# Average loss at step 54000: 3.425892
# Average loss at step 56000: 3.438174
# Average loss at step 58000: 3.397333
# Average loss at step 60000: 3.394568
# Nearest to its: their, his, her, the, your, my, gps, several,
# Nearest to known: regarded, such, used, described, thorax, well, part, defined,
# Nearest to it: he, there, she, this, methyl, now, which, congruence,
# Nearest to four: five, six, three, eight, seven, nine, two, zero,
# Nearest to were: are, was, have, had, fries, although, including, spyware,
# Nearest to b: d, c, f, n, r, yorker, stanzas, dividend,
# Nearest to states: kingdom, nations, airshows, state, countries, muppets, holocaust, clipping,
# Nearest to as: shadowed, californium, cuthbert, reformed, lakota, lesser, goodfellas, fermion,
# Nearest to history: demographics, vast, organizing, tlatelolco, art, list, regions, pharsalus,
# Nearest to or: and, biomechanics, including, than, like, osborne, splitter, ynys,
# Nearest to he: she, it, they, there, who, dylan, never, eventually,
# Nearest to also: now, often, still, actually, typically, sometimes, it, there,
# Nearest to than: much, hermeneutic, marche, or, but, ag, warrington, cadr,
# Nearest to would: could, will, may, can, must, should, might, cannot,
# Nearest to on: upon, through, in, at, transfusion, vast, diphtheria, curricula,
# Nearest to no: adas, little, any, delineated, asymptotic, rayner, cubans, collects,
# Average loss at step 62000: 3.244433
# Average loss at step 64000: 3.256182
# Average loss at step 66000: 3.400051
# Average loss at step 68000: 3.397500
# Average loss at step 70000: 3.362300
# Nearest to its: their, his, the, her, your, philanthropic, rooftops, my,
# Nearest to known: regarded, used, such, described, defined, thorax, repressing, sucked,
# Nearest to it: he, she, there, they, this, still, methyl, also,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to were: are, was, have, had, be, fries, including, while,
# Nearest to b: d, f, r, n, c, pete, scrub, stanzas,
# Nearest to states: kingdom, nations, state, countries, airshows, muppets, noa, holocaust,
# Nearest to as: shadowed, lesser, gloss, polycrates, cuthbert, forrestal, pluralist, petitcodiac,
# Nearest to history: list, art, book, map, demographics, mathematics, multinational, organizing,
# Nearest to or: and, like, than, any, but, hsieh, landmasses, while,
# Nearest to he: she, it, they, who, there, eventually, dylan, lyle,
# Nearest to also: now, still, often, which, typically, actually, generally, legally,
# Nearest to than: marche, much, or, hermeneutic, and, but, fingering, even,
# Nearest to would: could, will, may, can, must, should, might, cannot,
# Nearest to on: upon, through, in, curricula, at, vast, within, sip,
# Nearest to no: adas, little, any, delineated, asymptotic, planner, thermals, cubans,
# Average loss at step 72000: 3.368283
# Average loss at step 74000: 3.350897
# Average loss at step 76000: 3.315932
# Average loss at step 78000: 3.354928
# Average loss at step 80000: 3.376818
# Nearest to its: their, his, her, the, your, labs, our, gps,
# Nearest to known: used, regarded, such, defined, described, repressing, thorax, called,
# Nearest to it: he, she, there, this, they, still, not, we,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to were: are, was, had, been, have, fries, spyware, became,
# Nearest to b: d, f, pete, n, r, c, scrub, dividend,
# Nearest to states: kingdom, nations, state, countries, airshows, selector, muppets, noa,
# Nearest to as: dionysus, nellie, after, tishri, polycrates, before, shadowed, mueller,
# Nearest to history: list, vigo, wagner, consultative, biography, mathematics, vertex, organizing,
# Nearest to or: and, than, while, wavering, indispensable, armstrong, fontsize, sanctification,
# Nearest to he: she, it, they, there, who, never, detainee, soon,
# Nearest to also: now, often, still, which, typically, sometimes, never, tsing,
# Nearest to than: but, much, or, marche, and, far, fingering, hermeneutic,
# Nearest to would: will, could, can, may, must, might, should, cannot,
# Nearest to on: upon, through, in, at, curricula, cameos, agp, under,
# Nearest to no: little, adas, any, planner, alia, asymptotic, delineated, atomism,
# Average loss at step 82000: 3.408834
# Average loss at step 84000: 3.410892
# Average loss at step 86000: 3.392926
# Average loss at step 88000: 3.354363
# Average loss at step 90000: 3.367206
# Nearest to its: their, his, her, your, the, my, our, labs,
# Nearest to known: regarded, used, such, described, famous, repressing, defined, called,
# Nearest to it: he, she, there, this, they, itself, still, thus,
# Nearest to four: five, seven, six, eight, three, two, nine, one,
# Nearest to were: are, had, was, have, while, although, these, those,
# Nearest to b: d, pete, c, n, f, r, scrub, dividend,
# Nearest to states: kingdom, nations, airshows, countries, state, muppets, islands, clergy,
# Nearest to as: petitcodiac, mueller, islander, shadowed, lesser, nellie, dionysus, ethica,
# Nearest to history: list, vigo, wagner, courant, bureaucracies, coasts, consultative, phospholipid,
# Nearest to or: and, dhimma, quadrilateral, nonsensical, nee, hooks, sloth, chainsaw,
# Nearest to he: she, it, they, who, there, initially, later, soon,
# Nearest to also: now, often, still, which, sometimes, actually, who, never,
# Nearest to than: marche, much, exotic, but, vn, hermeneutic, sophisticated, far,
# Nearest to would: will, could, can, might, may, must, should, cannot,
# Nearest to on: upon, curricula, through, at, in, cameos, reappears, under,
# Nearest to no: little, any, adas, planner, atomism, hanse, rayner, only,
# Average loss at step 92000: 3.396370
# Average loss at step 94000: 3.250202
# Average loss at step 96000: 3.363717
# Average loss at step 98000: 3.245187
# Average loss at step 100000: 3.359279
# Nearest to its: their, his, her, the, your, horticulture, our, labs,
# Nearest to known: regarded, such, used, described, defined, possible, famous, repressing,
# Nearest to it: he, she, this, there, they, which, never, still,
# Nearest to four: seven, six, five, eight, three, two, nine, zero,
# Nearest to were: are, was, have, had, these, be, although, those,
# Nearest to b: d, warrior, pete, maffei, societal, domingo, bram, powering,
# Nearest to states: nations, kingdom, countries, islands, airshows, state, bm, sacked,
# Nearest to as: petitcodiac, pluralist, when, shadowed, tailed, like, lesser, ssl,
# Nearest to history: list, vigo, consultative, wagner, phospholipid, biography, courant, proselytizing,
# Nearest to or: and, than, tobin, medline, quadrilateral, wavering, prokaryotic, rida,
# Nearest to he: she, it, they, who, there, initially, we, never,
# Nearest to also: now, actually, often, still, sometimes, generally, typically, commonly,
# Nearest to than: or, marche, much, sophisticated, slightly, hyperthyroidism, way, invades,
# Nearest to would: will, could, may, might, can, must, should, did,
# Nearest to on: upon, in, within, at, through, transfusion, near, around,
# Nearest to no: little, any, adas, atomism, planner, alia, threes, propelled,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
